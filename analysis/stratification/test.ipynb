# %%
import numpy as np 
import matplotlib.pyplot as plt



# x = np.arange(-10, 10, 0.1)
z = np.arange(-10, 0, 0.1)
y = np.tanh(x)


base_temp = 15

# plt.plot(x, np.tanh(2*x), label="*2")

dt = 1.5 

def center_vector(vector, mult):
    x = abs(min(vector))
    vector = vector*2 + x 
    return vector*mult 

nz = center_vector(z, 0.25)
plt.plot(np.tanh(nz)*dt + base_temp, z , label="-1") # shifts curve to the right 
plt.legend()
ax = plt.gca()
ax.set_xlabel("temperature")
ax.set_ylabel("depth")
# Out:
# Text(0, 0.5, 'depth')
